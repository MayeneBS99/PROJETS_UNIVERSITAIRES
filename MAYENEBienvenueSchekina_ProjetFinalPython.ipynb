# %% [markdown]
# # Université de Lille | FST | Master 1 MIASHS MQME 2021-2022
#
# # MAYENE Bienvenue Schekina

# %% [markdown]
# ## Projet final : Cours Programmation en Python
#
#
# ### Plan :
#
# *Ce projet comporte trois grandes parties :*
# - I°). Inspection (comprehension de la base de données **'Thanksgiving'**)
# >- Importation des librairies
# >- Importation des données et recodage des classes (type)
#    des variables
# - II°). Analyse Univariée et Bivariée des données
# >- Tableaux de contingence
# >- Tests Statistiques
# >- Visualisation des données
# - III°). Analyse Avancée
# >- Utiliser des filtres et de selections dans les observations
# >- Utiliser des fonctions prédéfinies pour calculer et afficher des statistiques
# >- Utiliser nos propres fonctions et programmes pour calculer et afficher des statistiques
#
#
#
# ### -------------------------------------------- Méthode d'Evaluation ---------------------------------------------------------------
#
# **Dans cette section, nous vous expliquons comment faire et comment rendre ce projet :**
#
# - En effect vous utiliserez le fichier notebook nommé **NotebookProjetFinalPython.ipynb** se trouvant
#   dans le drive.
# - Et donc sur ce Notebook, vous créerez à chaque fois que nécessaire une nouvelle cellule en dessous de chaque
#   Question (tache à faire) dans laquelle vous mettrez votre réponse.
# - Pour plus de transparance, vous débuterez chacune de vos réponses par le commentaire **#MaReponse**
#   dans toute cellule que vous vous créerez.
# - Au moment de rendre le projet, nous vous demandons d'exécuter toutes vos cellules qu'elles marchent ou pas
# - Au moment de rendre le projet, nous vous demandons de renommer le fichier Notebook par exemple comme suit :
#   **TamsirDieng_ProjetFinalPython.ipynb**
# - Quand vous aurez fini c'est à dire à la dateline (**Vendredi 24 Juin 2022 A 17H00**),
#   je viendrai récupérer tous les scripts ou   Notebook sur une Clé USB (nous vous
#   recommandons de venir avec vos ordinateurs).

# %% [markdown]
# # I°). Inspection (comprehension) de la base de données

# %% [markdown]
# ## I.0 Importation des librairies et du dataset

# %% [markdown]
# - Importer les librairies :
# >- pandas
# >- matplotlib.pyplot
# >- numpy
# >- seaborn
# - Utiliser la fonction pandas.read_csv() pour lire le fichier 'thanksgiving.csv'.
# >- Spécifier dans les paramètres de la fonction l'argument **encoding='latin-1'** car ce dataset n'est pas encodé normalement
# >- Assigner le dataframe à la variable data
# - Afficher les premières lignes de data.
# - Afficher le nom des colonnes avec l'attribut columns.

# %%
#MaRéponse

#Importation des librairies

import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
import seaborn as sbn

# %%
#MaRéponse

# Importation de la base de données
data = pd.read_csv("thanksgiving.csv", encoding = "Latin-1")

# Affichage des premières lignes du dataset
data.head()
# Out:
#    RespondentID Do you celebrate Thanksgiving?  \
# 0    4337954960                            Yes
# 1    4337951949                            Yes
# 2    4337935621                            Yes
# 3    4337933040                            Yes
# 4    4337931983                            Yes
#
#   What is typically the main dish at your Thanksgiving dinner?  \
# 0                                             Turkey
# 1                                             Turkey
# 2                                             Turkey
# 3                                             Turkey
# 4                                           Tofurkey
#
#   What is typically the main dish at your Thanksgiving dinner? - Other (please specify)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# ...

# %%
# Ma réponse 

# Affichage du noms des vecteurs colonnes

columns = data.columns.tolist()
columns
# Out:
# ['RespondentID',
#  'Do you celebrate Thanksgiving?',
#  'What is typically the main dish at your Thanksgiving dinner?',
#  'What is typically the main dish at your Thanksgiving dinner? - Other (please specify)',
#  'How is the main dish typically cooked?',
#  'How is the main dish typically cooked? - Other (please specify)',
#  'What kind of stuffing/dressing do you typically have?',
#  'What kind of stuffing/dressing do you typically have? - Other (please specify)',
#  'What type of cranberry saucedo you typically have?',
#  'What type of cranberry saucedo you typically have? - Other (please specify)',
#  'Do you typically have gravy?',
#  'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Brussel sprouts',
#  'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Carrots',
# ...

# %% [markdown]
# ## I.1 Recodage des classes 'object' en 'category' dans le dataset

# %% [markdown]
# - Ecrire un programme qui vous permettra de convertir toutes les variables de type 'object' en 'category'.

# %%
#MaRéponse

#Affichage des classes
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1058 entries, 0 to 1057
# Data columns (total 65 columns):
#  #   Column                                                                                                                                        Non-Null Count  Dtype
# ---  ------                                                                                                                                        --------------  -----
#  0   RespondentID                                                                                                                                  1058 non-null   int64
#  1   Do you celebrate Thanksgiving?                                                                                                                1058 non-null   object
#  2   What is typically the main dish at your Thanksgiving dinner?                                                                                  974 non-null    object
# ...

# %%
# MaRéponse
# Programme pour convertir le type des variables en leurs classe par excellence


for i in range(len(columns)):
    if data.iloc[:, i].dtypes == "O":
        data.iloc[:, i] = pd.Categorical(data.iloc[:, i]) 
    
        
        
#Vérification du changement de classe des variables
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1058 entries, 0 to 1057
# Data columns (total 65 columns):
#  #   Column                                                                                                                                        Non-Null Count  Dtype
# ---  ------                                                                                                                                        --------------  -----
#  0   RespondentID                                                                                                                                  1058 non-null   int64
#  1   Do you celebrate Thanksgiving?                                                                                                                1058 non-null   category
#  2   What is typically the main dish at your Thanksgiving dinner?                                                                                  974 non-null    category
# ...

# %% [markdown]
# # II°). Analyse Univariée et Bivariée des données

# %% [markdown]
# ## II.0 Selection des variables à analyser

# %% [markdown]
# Dans un premier temps, nous allons faire un tri des variables sur lesquelles
# nous allons nous focaliser pour faire l'analyse univariée et bivariée des données.
#
# **Variables à analyser :**
# >- 'Do you celebrate Thanksgiving?' (**Variable Cible**)
# >- 'What is typically the main dish at your Thanksgiving dinner?'
# >- 'Do you typically have gravy?'
# >- 'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Apple'
# >- 'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pumpkin'
# >- 'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pecan'
# >- 'How far will you travel for Thanksgiving?'
# >- 'Age'
# >- 'What is your gender?'
# >- 'How much total combined money did all members of your HOUSEHOLD earn last year?'
# >- 'Have you ever tried to meet up with hometown friends on Thanksgiving night?'
# >- 'Have you ever attended a "Friendsgiving?"'

# %% [markdown]
# **Variables à analyser (traduites en français)**
#
# >- 'Célébrez-vous Thanksgiving ?' (Cible variable)
# >- 'Quel est généralement le plat principal de votre dîner de Thanksgiving ?'
# >- 'Avez-vous généralement de la sauce?'
# >- 'Quel type de tarte est généralement servi lors de votre dîner de Thanksgiving ? Veuillez sélectionner tout ceux qui s'appliquent. - Pomme'
# >- 'Quel type de tarte est généralement servi lors de votre dîner de Thanksgiving ? Veuillez sélectionner tout ceux qui s'appliquent. - Citrouille'
# >- 'Quel type de tarte est généralement servi lors de votre dîner de Thanksgiving ? Veuillez sélectionner tout ceux qui s'appliquent. - Noix de pécan
# >- 'Quelle distance parcourrez-vous pour Thanksgiving ?'
# >- 'Âge'
# >- 'Quel est votre sexe?'
# >- 'Combien d'argent total combiné tous les membres de votre FOYER ont-ils gagné l'année dernière ?'
# >- 'Avez-vous déjà essayé de rencontrer des amis de votre ville natale le soir de Thanksgiving?'
# >- 'Avez-vous déjà assisté à un "Friendsgiving?"'

# %% [markdown]
# ## II.1 Analyse Univariée
#
# - Faites l'analyse univariée de l'ensemble des variables citées ci-dessus (**section 2.0**).

# %% [markdown]
# Nous allons tout d'abord creer un dictionnaire qui ne permettra de connaitre la position de nos variables

# %%
#MaRéponse

dictionnaire_variables = {}
dictionnaire_variables.update(zip(columns, range(65)))
#cette fonction prend en entrée les valeurs associée aux différentes clés

print(dictionnaire_variables)
# Out:
# {'RespondentID': 0, 'Do you celebrate Thanksgiving?': 1, 'What is typically the main dish at your Thanksgiving dinner?': 2, 'What is typically the main dish at your Thanksgiving dinner? - Other (please specify)': 3, 'How is the main dish typically cooked?': 4, 'How is the main dish typically cooked? - Other (please specify)': 5, 'What kind of stuffing/dressing do you typically have?': 6, 'What kind of stuffing/dressing do you typically have? - Other (please specify)': 7, 'What type of cranberry saucedo you typically have?': 8, 'What type of cranberry saucedo you typically have? - Other (please specify)': 9, 'Do you typically have gravy?': 10, 'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Brussel sprouts': 11, 'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Carrots': 12, 'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select al
# ...

# %%
data.shape
# Out:
# (1058, 65)

# %%
#MaRéponse

#Statistique descriptives des variables selectionnées  avec la fonction .'describe()'
data.iloc[:, [1,2,10,26,34,33,52,61,62,63,55,56]].describe()
# Out:
#        Do you celebrate Thanksgiving?  \
# count                            1058
# unique                              2
# top                               Yes
# freq                              980
#
#        What is typically the main dish at your Thanksgiving dinner?  \
# count                                                 974
# unique                                                  8
# top                                                Turkey
# freq                                                  859
#
#        Do you typically have gravy?  \
# count                           974
# unique                            2
# top                             Yes
# freq                            892
#
#        Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Apple  \
# count                                                 514
# unique                                                  1
# ...

# %%
#MaRéponse

# Frequences (en pourcentages) des variables selectionnées
Liste = [1,2,10,26,34,33,52,61,62,63,55,56]
for i in Liste :
     print(pd.crosstab(data.iloc[:, i], 'freq', normalize = True) * 100)
# Out:
# col_0                                freq
# Do you celebrate Thanksgiving?
# No                               7.372401
# Yes                             92.627599
# col_0                                                    freq
# What is typically the main dish at your Thanksg...
# Chicken                                              1.232033
# Ham/Pork                                             2.977413
# I don't know                                         0.513347
# Other (please specify)                               3.593429
# Roast beef                                           1.129363
# Tofurkey                                             2.053388
# Turducken                                            0.308008
# Turkey                                              88.193018
# col_0                              freq
# Do you typically have gravy?
# No                             8.418891
# Yes                           91.581109
# ...

# %% [markdown]
# **COMMENTAIRES :**
#
# D'après les résultats obtenues, nous voyons que près de **93%** des individus de notre base de données célèbrent Thanksgiving contre 7% qui ne célèbrent pas cette fete.
#
# Les données montrent que le plat principal le plus servi à **88%** durant le dinner de thanksgiving est "Turkey" c'est à dire la dinde.
# Le plat le moins servi est "Turducken"
#
# >-**NB :** Le turducken ou dinde gigogne est un plat américain composé d’une dinde partiellement désossée, farcie d’un canard partiellement désossé, lui-même farci d’un poulet partiellement désossé
#
# **92%** des individus environ ont généralement de la sauce lors de leurs repas
#
# Nous constatons que les 514 individus ayant répondu à la question *'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Apple'* ont tous répondu qu'on leurs servaient une tarte à la pomme  généralement lors du dinner de Thanksgiving
#
# Nous constatons que les 729 individus ayant répondu à la question *'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pumpkin'* ont tous répondu qu'on leurs servaient généralement une tarte à la citrouille lors du dinner de Thanksgiving
#
# Nous constatons que les 342 individus ayant répondu à la question *'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pecan'* ont tous répondu qu'on leurs servaient généralement une tarte aux noix de pécan lors du dinner de Thanksgiving
#
# Les données nous montrent que notre base de données est composée en environ de **53% de femmes et 47% d'hommes.**
#
# **62%** des individus de notre base de données n'éssaient pas de rencontrer des amis de leurs ville natale le soir de Thanksgiving
# **72%** des individus de notre base n'ont jamais assisté à un Friendsgiving
#
# **42%** des individus de notre base fetent thanksgiving chez eux, ils ne se déplacent donc pas tandis que près de 9% seulement doivent conduire plusieurs heures ou prendre un vol pour pouvoir feter Thanksgiving
#
# Les individus de notre base sont le plus souvent agés de 45 à 59 ans
#
# Enfin, les données nous montrent que les familles ont le plus souvent gagné entre **25000 et 50000 dollard** l'année dernière.

# %% [markdown]
# ## II.2 Analyse Bivariée
#
# - En considérant la variable **'Do you celebrate Thanksgiving?'** comme **cible** ou **dépendante**
# - En vous basant des **tableaux de contingence** étudier la dépendance notée entre chacune des variables
#   citées ci-dessus (**section 2.0**) par rapport à la variable considérée comme cible.
# - Chaque tableau doit s'accompagner d'un **test statistique** approprié.

# %% [markdown]
# En essayant de faire le tableau de contingence entre la variable cible et les autres variables, nous nous sommes rendu compte
# que pour certaine variable la modalité "No" de la variable cible n'apparaissait pas dans le tableau ce qui est logique.
#
# En effet ceux qui ne célèbrent pas Thanksgiving n'ont certainement pas répondu aux autres questions qui sont en rapport avec cette fête.
#
# Nous effectuerons donc notre analyse bivariée entre la variable cible et les variables suivantes :
# >- 'Age'
# >- 'What is your gender?'
# >- 'How much total combined money did all members of your HOUSEHOLD earn last year?'
#
# Nos tableaux de contingence seront accompagnés d'un test statistique approprié

# %% [markdown]
# ### Tableau 1

# %%
#MaRéponse
#tableau de contingence entre la variable cible et la variable 'Age'
# NB: Variable cible en ordonnée et Variable indépendante en abcisse
tableau1 = pd.crosstab(data.iloc[:, 61], data.iloc[:, 1], normalize = "index", margins = False)

#Affichage
tableau1
# Out:
# Do you celebrate Thanksgiving?        No       Yes
# Age
# 18 - 29                         0.143519  0.856481
# 30 - 44                         0.092664  0.907336
# 45 - 59                         0.059441  0.940559
# 60+                             0.022727  0.977273

# %%
#MaRéponse

#tableau de contingence
tab = pd.crosstab(data.iloc[:, 61], data.iloc[:, 1])

import scipy.stats as sp
#Test de comparaison de deux variables qualitatives
sp.chi2_contingency(tab)
# Out:
# (26.80050541537051,
#  6.4824283775674256e-06,
#  3,
#  array([[ 16.43707317, 199.56292683],
#         [ 19.70926829, 239.29073171],
#         [ 21.76390244, 264.23609756],
#         [ 20.0897561 , 243.9102439 ]]))

# %% [markdown]
# ### Tableau 2

# %%
#MaRéponse
#tableau de contingence
tableau2 = pd.crosstab(data.iloc[:, 62], data.iloc[:, 1], normalize = "index", margins = False)

#Affichage
tableau2
# Out:
# Do you celebrate Thanksgiving?        No       Yes
# What is your gender?
# Female                          0.053309  0.946691
# Male                            0.101871  0.898129

# %%
#MaRéponse

#tableau de contingence
tab2 = pd.crosstab(data.iloc[:, 62], data.iloc[:, 1])

#Test de comparaison de deux variables qualitatives
sp.chi2_contingency(tab2)
# Out:
# (7.886118591179945,
#  0.004981565793292484,
#  1,
#  array([[ 41.39707317, 502.60292683],
#         [ 36.60292683, 444.39707317]]))

# %% [markdown]
# ### Tableau 3

# %%
#MaRéponse
#tableau de contingence
tableau3 = pd.crosstab(data.iloc[:, 63], data.iloc[:, 1], normalize = "index", margins = False)

#Affichage
tableau3
# Out:
# Do you celebrate Thanksgiving?                            No       Yes
# How much total combined money did all members o...
# $0 to $9,999                                        0.212121  0.787879
# $10,000 to $24,999                                  0.117647  0.882353
# $100,000 to $124,999                                0.018018  0.981982
# $125,000 to $149,999                                0.020408  0.979592
# $150,000 to $174,999                                0.050000  0.950000
# $175,000 to $199,999                                0.037037  0.962963
# $200,000 and up                                     0.050000  0.950000
# $25,000 to $49,999                                  0.077778  0.922222
# $50,000 to $74,999                                  0.059259  0.940741
# $75,000 to $99,999                                  0.045113  0.954887
# Prefer not to answer                                0.132353  0.867647

# %%
#MaRéponse

#tableau de contingence
tab3 = pd.crosstab(data.iloc[:, 63], data.iloc[:, 1])

import scipy.stats as sp
#Test de comparaison de deux variables qualitatives
sp.chi2_contingency(tab3)
# Out:
# (36.76373234183881,
#  6.217366781897338e-05,
#  10,
#  array([[  5.02243902,  60.97756098],
#         [  5.17463415,  62.82536585],
#         [  8.44682927, 102.55317073],
#         [  3.72878049,  45.27121951],
#         [  3.04390244,  36.95609756],
#         [  2.05463415,  24.94536585],
#         [  6.08780488,  73.91219512],
#         [ 13.69756098, 166.30243902],
#         [ 10.27317073, 124.72682927],
#         [ 10.12097561, 122.87902439],
#         [ 10.34926829, 125.65073171]]))

# %% [markdown]
# ## II.3 Visualisation des données
#
# - En considérant la variable **'Do you celebrate Thanksgiving?'** comme **cible** ou **dépendante**
# - Utiliser cette fois-ci des **Graphiques ou Diagrammes** pour étudier la dépendance notée entre chacune des variables
#   citées ci-dessus (**section 2.0**) par rapport à la variable considérée comme cible.

# %% [markdown]
# Nous savons plus ou moins que ceux qui ne célèbrent pas Thanksgiving n'ont certainement pas répondu aux autres questions qui sont en rapport avec cette fête.
#
# Nous effectuerons donc la visualisation de nos diagrammes entre la variable cible et les variables suivantes :
# >- 'Age'
# >- 'What is your gender?'
# >- 'How much total combined money did all members of your HOUSEHOLD earn last year?'

# %%
#MaRéponse
fig = plt.figure(figsize = (12,15))

Variables = ['Age','What is your gender?','How much total combined money did all members of your HOUSEHOLD earn last year?']

for i in range(len(Variables)):
    plt.subplot(3,1,  i+1)
    sbn.countplot(x = Variables[i] , hue= "Do you celebrate Thanksgiving?",
                 palette = "Blues", data = data)
    plt.xticks(rotation = 45)
    plt.legend(loc = 'upper right')

    
plt.show()

# %%
fig = plt.figure(figsize = (13,40))

Variables = ['What is typically the main dish at your Thanksgiving dinner?',
'Do you typically have gravy?',
'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Apple',
'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pumpkin',
'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pecan',
'How far will you travel for Thanksgiving?',
'Age',
'What is your gender?',
'How much total combined money did all members of your HOUSEHOLD earn last year?',
'Have you ever tried to meet up with hometown friends on Thanksgiving night?',
'Have you ever attended a "Friendsgiving?"']

for i in range(len(Variables)):
    plt.subplot(4,3,  i+1)
    sbn.countplot(x = Variables[i] , hue= "Do you celebrate Thanksgiving?",
                 palette = "Blues", data = data)
    plt.xticks(rotation = 45)
    plt.legend(loc = 'upper right')

    
plt.show()

# %% [markdown]
# ## II.4 Conclusion :
#
# - En vous basant des statistiques notées à travers vos **tableaux de contingence**, **Graphiques visuels** et
#   **test statistique**, rédiger un mini rapport résumant toutes les dépendances observées entre la variable cible et
#   chacune des autres variables citées ci-dessus (**section 2.0**).

# %% [markdown]
# **RAPPORT D'ANALYSE**
#
# Près de 98% des personnes de plus de 60 ans célèbrent Thanksgiving contre près de 86% des personnes agées entre 18 et 29 ans.
# Près de 2,27% des personnes de plus de 60 ans ne célèbrent pas Thanksgiving contre près de 14% des personnes agées entre 18 et 29 ans.
# Nous pouvons donc dire que les individus plus agés célèbrent plus Thanksgiving que les plus jeunes.
#
# En effectuant le test de khi-deux, test nous permettant de voir s'il existe une dependance entre nos variables qualitatives, nous voyons que **p_value = 6.4824283775674256e-06 < inferieure au seuil de 0.05**
#
# Concusion: **Rejet de l'hypothèse nulle d'indépendance**, Autrement dit il existe une dépendance entre l'age et la célebration de Thanksgiving
#
#
#
# Près de 95% des femmes célèbrent Thanksgiving contre près de 89,8% des hommes.
# Près de 5% des femmes ne célèbrent pas Thanksgiving contre près de 10% des hommes.
#
# En effectuant le test de khi-deux, test nous permettant de voir s'il existe une dependance entre nos variables qualitatives, nous voyons que **p_value = 0.004981565793292484  < inferieure au seuil de 0.05**
#
# Concusion: **Rejet de l'hypothèse nulle d'indépendance**, Autrement dit il existe une dépendance entre le sexe et la célebration de Thanksgiving
#
#
#
# Près de 98% des personnes qui ont gagné entre 100.000 et 125.000 dollard l'année dernière célèbrent Thanksgiving contre près de 79% des personnes qui ont gagné entre 0 et 1.000 dollard
# Près de 1,8% des personnes qui ont gagné entre 100.000 et 125.000 dollard ne célèbrent pas Thanksgiving contre près de 21% des personnes qui ont gagné entre 0 et 1.000 dollard.
#
# En effectuant le test de khi-deux, test nous permettant de voir s'il existe une dependance entre nos variables qualitatives, nous voyons que **p_value = 6.217366781897338e-05 < inferieure au seuil de 0.05**
#
# Concusion: **Rejet de l'hypothèse nulle d'indépendance**, Autrement dit il existe une dépendance entre l'argent perçue l'année dernière par les familles et la célebration de Thanksgiving

# %% [markdown]
# # III°). Analyse Avancée

# %% [markdown]
# ## III.1 Filtrer des données

# %% [markdown]
# - Utiliser la méthode Series.value_counts() pour afficher le décompte du nombre de réponses pour chaque catégorie de la colonne 'Do you celebrate Thanksgiving?'.
# - Filtrer et garder toutes les lignes du dataframe data pour lesquelles la réponse à la question 'Do you celebrate Thanksgiving?' est 'Yes'.
# - Assigner ce nouveau dataframe à data et afficher le.

# %%
#MaRéponse 

#Affichage du decompte du nombre de réponses de chaque catégorie 
data.iloc[:, 1].value_counts()
# Out:
# Yes    980
# No      78
# Name: Do you celebrate Thanksgiving?, dtype: int64

# %%
#MaRéponse 
#Filtrage
individus_yes = data.iloc[:, 1]=="Yes"
individus_yes
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1053    True
# 1054    True
# 1055    True
# 1056    True
# 1057    True
# Name: Do you celebrate Thanksgiving?, Length: 1058, dtype: bool

# %%
#MaRéponse
data= data.loc[individus_yes]
data
# Out:
#       RespondentID Do you celebrate Thanksgiving?  \
# 0       4337954960                            Yes
# 1       4337951949                            Yes
# 2       4337935621                            Yes
# 3       4337933040                            Yes
# 4       4337931983                            Yes
# ...            ...                            ...
# 1053    4335944082                            Yes
# 1054    4335943173                            Yes
# 1055    4335943060                            Yes
# 1056    4335934708                            Yes
# 1057    4335894916                            Yes
#
#      What is typically the main dish at your Thanksgiving dinner?  \
# 0                                                Turkey
# 1                                                Turkey
# 2                                                Turkey
# 3                                                Turkey
# 4                                              Tofurkey
# ...

# %% [markdown]
# ## III.2 Exploration des repas de thanksgiving

# %% [markdown]
# - Utiliser la méthode Series.value_counts() pour afficher combien de fois chaque résultat apparaît pour la question et colonne 'What is typically the main dish at your Thanksgiving dinner?'.
# - Afficher la colonne 'Do you typically have gravy?' pour les lignes du dataframe data pour lesquelles la colonne 'What is typically the main dish at your Thanksgiving dinner?' vaut 'Tofurkey' pour la dinde de tofu.
# >- Créer un filtre qui sélectionne seulement les lignes du dataframe data où 'What is typically the main dish at your Thanksgiving dinner?' vaut 'Tofurkey'
# >- Assigner le résultat à la variable tofurkey
# >- Afficher la colonne 'Do you typically have gravy?' de ce nouveau dataframe tofurkey

# %%
#MaRéponse

data2.iloc[:, 2].value_counts()
# Out:
# Turkey                    859
# Other (please specify)     35
# Ham/Pork                   29
# Tofurkey                   20
# Chicken                    12
# Roast beef                 11
# I don't know                5
# Turducken                   3
# Name: What is typically the main dish at your Thanksgiving dinner?, dtype: int64

# %%
#MaRéponse
Tofurkey = data.loc[data.iloc[:, 2]=="Tofurkey"]
Tofurkey
# Out:
#      RespondentID Do you celebrate Thanksgiving?  \
# 4      4337931983                            Yes
# 33     4337771439                            Yes
# 69     4337553422                            Yes
# 72     4337540484                            Yes
# 77     4337490067                            Yes
# 145    4337191550                            Yes
# 175    4337139327                            Yes
# 218    4337078951                            Yes
# 243    4337044348                            Yes
# 275    4336997445                            Yes
# 393    4336894719                            Yes
# 399    4336891075                            Yes
# 571    4336760110                            Yes
# 594    4336736562                            Yes
# 628    4336692873                            Yes
# 774    4336400854                            Yes
# 820    4336238126                            Yes
# 837    4336175740                            Yes
# ...

# %%
#MaRéponse
#Affichage de la colonne
Tofurkey.iloc[:, 10]
# Out:
# 4      Yes
# 33     Yes
# 69      No
# 72      No
# 77     Yes
# 145    Yes
# 175    Yes
# 218     No
# 243    Yes
# 275     No
# 393    Yes
# 399    Yes
# 571    Yes
# 594    Yes
# 628     No
# 774     No
# 820     No
# 837    Yes
# 860     No
# 953    Yes
# Name: Do you typically have gravy?, dtype: category
# Categories (2, object): ['No', 'Yes']

# %% [markdown]
# ## III.3 Tendances des desserts pour Thanksgiving

# %% [markdown]
# - Créer un objet Series indiquant avec des booléens les valeurs de la colonne 'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Apple' qui sont nulles. Assigner le résultat à la variable apple_isnull.
# - Créer un objet Series indiquant avec des booléens les valeurs de la colonne 'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pumpkin' qui sont nulles. Assigner le résultat à la variable pumpkin_isnull.
# - Créer un objet Series indiquant avec des booléens les valeurs de la colonne 'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pecan' qui sont nulles. Assigner le résultat à la variable pecan_isnull.
# - Combiner ces 3 objets Series avec l'opérateur & et assigner le résultat à la variable pies.
# - Afficher les valeurs uniques et combien de fois elles apparaissent dans la colonne de pies.

# %%
#MaRéponse 
apple_is_null = pd.isnull(data2.iloc[:, 26])
apple_is_null
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 1053     True
# 1054     True
# 1055    False
# 1056     True
# 1057     True
# Name: Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Apple, Length: 980, dtype: bool

# %%
#MaRéponse 
pumpkin_isnull = pd.isnull(data2.iloc[:, 34])
pumpkin_isnull
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1053    False
# 1054    False
# 1055     True
# 1056     True
# 1057     True
# Name: Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pumpkin, Length: 980, dtype: bool

# %%
#MaRéponse 
pecan_isnull = pd.isnull(data2.iloc[:, 33])
pecan_isnull
# Out:
# 0        True
# 1        True
# 2       False
# 3       False
# 4        True
#         ...
# 1053    False
# 1054     True
# 1055     True
# 1056     True
# 1057     True
# Name: Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pecan, Length: 980, dtype: bool

# %%
#MaRéponse 
data["pies"] = apple_is_null & pumpkin_isnull & pecan_isnull
data
# Out:
#       RespondentID Do you celebrate Thanksgiving?  \
# 0       4337954960                            Yes
# 1       4337951949                            Yes
# 2       4337935621                            Yes
# 3       4337933040                            Yes
# 4       4337931983                            Yes
# ...            ...                            ...
# 1053    4335944082                            Yes
# 1054    4335943173                            Yes
# 1055    4335943060                            Yes
# 1056    4335934708                            Yes
# 1057    4335894916                            Yes
#
#      What is typically the main dish at your Thanksgiving dinner?  \
# 0                                                Turkey
# 1                                                Turkey
# 2                                                Turkey
# 3                                                Turkey
# 4                                              Tofurkey
# ...

# %%
#MaRéponse 
data["pies"].value_counts()
# Out:
# False    876
# True     104
# Name: pies, dtype: int64

# %% [markdown]
# ## III.4 Convertir l'âge en une valeur numérique

# %% [markdown]
# - Ecrire une fonction qui convertit une chaine de caractères en une valeur entière. Cela permettra de convertir les valeurs de la colonne 'Age' en entiers. Cette fonction prendra en paramètre une chaine de caractères (les valeurs actuelles de la colonne 'Age')
# >- Utiliser la fonction isnull() pour vérifier si les valeurs sont nulles. Ajouter une condition if qui retourne 'None' si la valeur est nulle
# >- Séparer les chaines de caractères en fonction de l'espace (' ') et extraire le premier élément de la liste résultante (méthode split())
# >- Remplacer le caractère '+' dans le résultat avec une chaine de caractères vide en remplacement pour le supprimer (méthode replace())
# >- utiliser int() pour convertir le résultat en entier
# >- Retourner le résultat
# - Utiliser la méthode Series.apply() pour appliquer la fonction à chaque valeur de la colonne 'Age' du dataframe data.
# >- Assigner le résultat à la nouvelle colonne int_age du dataframe data
# - Appeler la méthode Series.describe() sur la colonne 'int_age' du dataframe data et afficher le résultat.

# %%
#MaRéponse
# Ecrivons la fonction 
def fonction_VI(chainec):
    if pd.isnull(chainec)==True:
        return None
    if pd.isnull(chainec)==False :
        liste = chainec.split(' ')
        resultat = liste[0]
        res= resultat.replace('+', '')
        final_res = int(res)
    return final_res
        
#testons notre fonction 
param = '60+'
verif= fonction_VI(param)
print(verif)
# Out:
# 60

# %%
#MaRéponse
#Création de la nouvelle variable "int_age"
data["int_age"] = data.iloc[:, 61].apply(fonction_VI)

#affichage 
data
# Out:
#       RespondentID Do you celebrate Thanksgiving?  \
# 0       4337954960                            Yes
# 1       4337951949                            Yes
# 2       4337935621                            Yes
# 3       4337933040                            Yes
# 4       4337931983                            Yes
# ...            ...                            ...
# 1053    4335944082                            Yes
# 1054    4335943173                            Yes
# 1055    4335943060                            Yes
# 1056    4335934708                            Yes
# 1057    4335894916                            Yes
#
#      What is typically the main dish at your Thanksgiving dinner?  \
# 0                                                Turkey
# 1                                                Turkey
# 2                                                Turkey
# 3                                                Turkey
# 4                                              Tofurkey
# ...

# %%
#Convertir la variable  'int_age' en entier
data["int_age"] = data.int_age.astype('float64') 

#type des variables
print(data.dtypes)
# Out:
# RespondentID                                                                                int64
# Do you celebrate Thanksgiving?                                                           category
# What is typically the main dish at your Thanksgiving dinner?                             category
# What is typically the main dish at your Thanksgiving dinner? - Other (please specify)    category
# How is the main dish typically cooked?                                                   category
#                                                                                            ...
# What is your gender?                                                                     category
# How much total combined money did all members of your HOUSEHOLD earn last year?          category
# US Region                                                                                category
# int_age                                                                                   float64
# ...

# %%
#MaRéponse
data["int_age"].describe()
# Out:
# count    947.000000
# mean      40.089757
# std       15.352014
# min       18.000000
# 25%       30.000000
# 50%       45.000000
# 75%       60.000000
# max       60.000000
# Name: int_age, dtype: float64

# %% [markdown]
# ## III.5 Convertir les revenus en valeurs numériques

# %% [markdown]
# - Ecrire une fonction pour convertir les revenus en valeur unique de format entier.
# >- Utiliser la fonction isnull() pour vérifier si la valeur est nulle. Si c'est le cas, retourner 'None'
# >- Séparer la chaine de caractères en prenant l'espace comme délimiteur et extraire le premier élément de la liste résultante
# >- Si le résultat vaut 'Prefer', retourner 'none'
# >- Remplacer les caractères '$' et ',' par des chaines de caractères vides pour les supprimer
# >- Utiliser int() pour convertir le résultat en entier
# >- Retourner le résultat
# - Utiliser la méthode Series.apply() pour appliquer la fonction précédente à chaque valeur de la colonne 'How much total combined money did all members of your HOUSEHOLD earn last year?' du dataframe data.
# >- Assigner le résultat à la nouvelle colonne 'int_income' du dataframe data
# - Appeler la méthode Series.describe() à la colonne int_income du dataframe data et afficher le résultat.

# %%
#MaRéponse
def fonction_VUE(revstr):
    if pd.isnull(revstr)==True:
        return None
    if pd.isnull(revstr)==False :
        liste = revstr.split(' ')
        resultat = liste[0]
        if resultat == 'Prefer':
            return None
        else :
            res= resultat.replace("$", '')
            res1= res.replace(",", "")
            final_res = int(res1)
        
        
    return final_res
        
#testons la fonction 
param = '$50,000 - $69,999'
verif= fonction_VUE(param)
print(verif)
# Out:
# 50000

# %%
#MaRéponse
data["int_income"] = data.iloc[:, 63].apply(fonction_VUE) 

data
# Out:
#       RespondentID Do you celebrate Thanksgiving?  \
# 0       4337954960                            Yes
# 1       4337951949                            Yes
# 2       4337935621                            Yes
# 3       4337933040                            Yes
# 4       4337931983                            Yes
# ...            ...                            ...
# 1053    4335944082                            Yes
# 1054    4335943173                            Yes
# 1055    4335943060                            Yes
# 1056    4335934708                            Yes
# 1057    4335894916                            Yes
#
#      What is typically the main dish at your Thanksgiving dinner?  \
# 0                                                Turkey
# 1                                                Turkey
# 2                                                Turkey
# 3                                                Turkey
# 4                                              Tofurkey
# ...

# %%
#MaRéponse
data.int_income.describe()
# Out:
# count       829.000000
# mean      75965.018094
# std       59068.636748
# min           0.000000
# 25%       25000.000000
# 50%       75000.000000
# 75%      100000.000000
# max      200000.000000
# Name: int_income, dtype: float64

# %% [markdown]
# ## III.6 Corrélation entre distance et revenus

# %% [markdown]
# - Regarder de quelle manière les personnes gagnant moins de 150000 dollars voyagent.
# >- Filtrer data en sélectionnant seulement les valeurs de 'int_income' inférieures à 150000
# >- Sélectionner la colonne 'How far will you travel for Thanksgiving?' en prenant en compte le filtre
# >- Utiliser la méthode value_counts() pour compter combien de fois chaque valeur apparaît dans la colonne
# >- Afficher les résultats
# - Faire de même avec les personnes gagnant plus de 150000 dollars.

# %% [markdown]
# **Personne gagnant moins de 150.000$**

# %%
#MaRéponse
indv_solde_inf = data.loc[data['int_income']< 150000]
indv_solde_inf
# Out:
#       RespondentID Do you celebrate Thanksgiving?  \
# 0       4337954960                            Yes
# 1       4337951949                            Yes
# 2       4337935621                            Yes
# 4       4337931983                            Yes
# 5       4337929779                            Yes
# ...            ...                            ...
# 1050    4335945415                            Yes
# 1051    4335944854                            Yes
# 1053    4335944082                            Yes
# 1054    4335943173                            Yes
# 1055    4335943060                            Yes
#
#      What is typically the main dish at your Thanksgiving dinner?  \
# 0                                                Turkey
# 1                                                Turkey
# 2                                                Turkey
# 4                                              Tofurkey
# 5                                                Turkey
# ...

# %%
#MaRéponse
#Selection de la colonne en prennant en compte le filtre
indv_solde_inf.iloc[:, 52].value_counts()
# Out:
# Thanksgiving is happening at my home--I won't travel at all                         281
# Thanksgiving is local--it will take place in the town I live in                     203
# Thanksgiving is out of town but not too far--it's a drive of a few hours or less    150
# Thanksgiving is out of town and far away--I have to drive several hours or fly       55
# Name: How far will you travel for Thanksgiving?, dtype: int64

# %% [markdown]
# **Personne gagnant plus de 150.000$**

# %%
#MaRéponse
indv_solde_sup = data.loc[data['int_income']> 150000]
indv_solde_sup
# Out:
#       RespondentID Do you celebrate Thanksgiving?  \
# 3       4337933040                            Yes
# 15      4337857295                            Yes
# 16      4337856362                            Yes
# 25      4337790002                            Yes
# 39      4337732348                            Yes
# ...            ...                            ...
# 982     4335981057                            Yes
# 983     4335979596                            Yes
# 993     4335973959                            Yes
# 1015    4335960288                            Yes
# 1026    4335957096                            Yes
#
#      What is typically the main dish at your Thanksgiving dinner?  \
# 3                                                Turkey
# 15                                               Turkey
# 16                                            Turducken
# 25                                               Turkey
# 39                                             Ham/Pork
# ...

# %%
#MaRéponse
#Selection de la colonne en prennant en compte le filtre
indv_solde_sup.iloc[:, 52].value_counts()
# Out:
# Thanksgiving is happening at my home--I won't travel at all                         49
# Thanksgiving is local--it will take place in the town I live in                     25
# Thanksgiving is out of town but not too far--it's a drive of a few hours or less    16
# Thanksgiving is out of town and far away--I have to drive several hours or fly      12
# Name: How far will you travel for Thanksgiving?, dtype: int64

# %% [markdown]
# ## III.7 Lien entre passer Thanksgiving entre amis avec l'âge et le revenu

# %% [markdown]
# - Générer un pivot de table montrant la moyenne d'âge des sondés pour chaque catégorie des questions 'Have you ever tried to meet up with hometown friends on Thanksgiving night?' et 'Have you ever attended a "Friendsgiving?"'.
# >- Appeler la méthode pivot_table() sur le dataframe data
# >- Passer au paramètre 'index' la valeur 'Have you ever tried to meet up with hometown friends on Thanksgiving night?'
# >- Passer au paramètre 'columns' la valeur 'Have you ever attended a "Friendsgiving?"'
# >- Passer au paramètre 'values' la valeur 'int_age'
# >- Afficher les résultats
# - Faire de même pour les revenues avec ces 2 questions.

# %% [markdown]
# **Pivot de table avec la variable 'Age'**

# %%
help(pd.pivot_table)

# %%
#MaRéponse
(pd.pivot_table(data, values='int_age', index= data.iloc[:, 55],
                         columns=data.iloc[:, 56]).astype(int))
# Out:
# Have you ever attended a "Friendsgiving?"           No  Yes
# Have you ever tried to meet up with hometown fr...
# No                                                  42   37
# Yes                                                 41   33

# %% [markdown]
# **Pivot de table avec la variable 'int_income'**

# %%
#MaRéponse
pd.pivot_table(data, values='int_income', index= data.iloc[:, 55],
                         columns=data.iloc[:, 56], aggfunc=np.mean )
# Out:
# Have you ever attended a "Friendsgiving?"                     No           Yes
# Have you ever tried to meet up with hometown fr...
# No                                                  78914.549654  72894.736842
# Yes                                                 78750.000000  66019.736842

# %% [markdown]
# - **---> A Rendre le Vendredi 24 Juin 2022 à 17H00 en présentiel sous format
#   éléctronique (je viendrai les récupérer dans une clé USB)**

# %% [markdown]
# # Bonne Chance, même si elle est toujours bonne !!!
